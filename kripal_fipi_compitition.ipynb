# %%
#Importing Required Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
#Importing Dataset 
df=pd.read_csv("input_data_quiz.csv")
df
# Out:
#       NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0                 5599.0          15/9-F-12          11.50
# 1                 5599.0          15/9-F-12          24.00
# 2                 5599.0          15/9-F-12          22.50
# 3                 5599.0          15/9-F-12          23.15
# 4                 5599.0          15/9-F-12          24.00
# ...                  ...                ...            ...
# 2495              5599.0          15/9-F-12          24.00
# 2496              5599.0          15/9-F-12          24.00
# 2497              5599.0          15/9-F-12          24.00
# 2498              5599.0          15/9-F-12          24.00
# 2499              5599.0          15/9-F-12          24.00
#
#       AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# 0                   308.056                   104.418        201.250
# 1                   303.034                   105.403        182.145
# 2                   295.586                   105.775        181.868
# 3                   297.663                   105.752        180.832
# 4                   295.936                   105.811        180.501
# ...                     ...                       ...            ...
# 2495                  0.000                     0.000         54.106
# 2496                  0.000                     0.000         53.827
# 2497                  0.000                     0.000         53.484
# 2498                  0.000                     0.000         53.008
# 2499                  0.000                     0.000         52.808
#
#       AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P  AVG_WHP_P  AVG_WHT_P  \
# 0                18.640          14.48443    106.806     16.295
# 1                16.467          22.83299    120.889     53.374
# 2                12.660          31.24997    113.718     72.738
# 3                 5.264          28.51893    116.831     69.996
# 4                12.385          30.22790    115.434     71.518
# ...                 ...               ...        ...        ...
# 2495             28.866          34.36061     54.106     68.550
# 2496             29.012          33.65804     53.827     71.856
# 2497             28.842          34.58774     53.484     71.553
# 2498             28.691          34.80917     53.008     71.980
# 2499             28.859          34.94795     52.808     72.518
#
#       DP_CHOKE_SIZE  BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL
# 0            92.475         285.0       38889.0         385.0
# 1            89.620        1870.0      285246.0           7.0
# 2            80.120        3124.0      509955.0           1.0
# 3            84.251        2608.0      383427.0           1.0
# 4            82.359        3052.0      418474.0           5.0
# ...             ...           ...           ...           ...
# 2495         25.420         694.0      105168.0         698.0
# 2496         25.148         692.0      104778.0         697.0
# 2497         24.808         707.0      106179.0         705.0
# 2498         24.331         706.0      104809.0         705.0
# 2499         24.146         707.0      104707.0         710.0
#
# [2500 rows x 14 columns]

# %%
df['NPD_WELL_BORE_CODE'].value_counts()
# Out:
# 5599.0    2498
# Name: NPD_WELL_BORE_CODE, dtype: int64

# %%
#pd.plotting.scatter_matrix(df)

# %%
plt.style.use('ggplot')

# %%
sns.heatmap(df.corr(),square=True,cmap='RdYlGn')
# Out:
# <AxesSubplot:>

# %%
print(df.var())
# Out:
# NPD_WELL_BORE_CODE          0.000000e+00
# ON_STREAM_HRS               4.859460e+01
# AVG_DOWNHOLE_PRESSURE       1.586288e+04
# AVG_DOWNHOLE_TEMPERATURE    2.675233e+03
# AVG_DP_TUBING               5.561945e+03
# AVG_ANNULUS_PRESS           4.327999e+01
# AVG_CHOKE_SIZE_P            8.917447e+02
# AVG_WHP_P                   5.961552e+02
# AVG_WHT_P                   3.996192e+02
# DP_CHOKE_SIZE               5.537449e+02
# BORE_OIL_VOL                3.014684e+06
# BORE_GAS_VOL                6.009186e+10
# BORE_WAT_VOL                4.234593e+06
# dtype: float64

# %%
df = np.round(df)

# %%
#Boxplot to see outliers
figuresizes = (10,7)
plt.figure(figsize=figuresizes)
sns.boxplot(x = 'NPD_WELL_BORE_CODE', y = 'ON_STREAM_HRS', data=df)

plt.figure(figsize=figuresizes)
sns.boxplot(x = 'NPD_WELL_BORE_CODE', y = 'AVG_DOWNHOLE_PRESSURE', data=df)

plt.figure(figsize=figuresizes)
sns.boxplot(x = 'NPD_WELL_BORE_CODE', y = 'AVG_DOWNHOLE_TEMPERATURE', data=df)

plt.figure(figsize=figuresizes)
sns.boxplot(x = 'NPD_WELL_BORE_CODE', y = 'AVG_DP_TUBING', data=df)

plt.figure(figsize=figuresizes)
sns.boxplot(x = 'NPD_WELL_BORE_CODE', y = 'AVG_ANNULUS_PRESS', data=df)

plt.figure(figsize=figuresizes)
sns.boxplot(x = 'NPD_WELL_BORE_CODE', y = 'AVG_CHOKE_SIZE_P', data=df)

plt.figure(figsize=figuresizes)
sns.boxplot(x = 'NPD_WELL_BORE_CODE', y = 'AVG_WHP_P', data=df)

plt.figure(figsize=figuresizes)
sns.boxplot(x = 'NPD_WELL_BORE_CODE', y = 'AVG_WHT_P', data=df)

plt.figure(figsize=figuresizes)
sns.boxplot(x = 'NPD_WELL_BORE_CODE', y = 'DP_CHOKE_SIZE', data=df)

plt.figure(figsize=figuresizes)
sns.boxplot(x = 'NPD_WELL_BORE_CODE', y = 'BORE_OIL_VOL', data=df)

plt.figure(figsize=figuresizes)
sns.boxplot(x = 'NPD_WELL_BORE_CODE', y = 'BORE_GAS_VOL', data=df)

plt.figure(figsize=figuresizes)
sns.boxplot(x = 'NPD_WELL_BORE_CODE', y = 'BORE_WAT_VOL', data=df)
# Out:
# <AxesSubplot:xlabel='NPD_WELL_BORE_CODE', ylabel='BORE_WAT_VOL'>

# %%
#fill the NaN value using pad method
df['ON_STREAM_HRS'] = df['ON_STREAM_HRS'].fillna(method='pad')
df['AVG_DOWNHOLE_PRESSURE'] = df['AVG_DOWNHOLE_PRESSURE'].fillna(method='pad')
df['AVG_DOWNHOLE_TEMPERATURE'] = df['AVG_DOWNHOLE_TEMPERATURE'].fillna(method='pad')
df['AVG_DP_TUBING'] = df['AVG_DP_TUBING'].fillna(method='pad')
df['AVG_ANNULUS_PRESS'] = df['AVG_ANNULUS_PRESS'].fillna(method='pad')
df['AVG_CHOKE_SIZE_P'] = df['AVG_CHOKE_SIZE_P'].fillna(method='pad')
df['AVG_WHP_P'] = df['AVG_WHP_P'].fillna(method='pad')
df['AVG_WHT_P'] = df['AVG_WHT_P'].fillna(method='pad')
df['DP_CHOKE_SIZE'] = df['DP_CHOKE_SIZE'].fillna(method='pad')
df['BORE_OIL_VOL'] = df['BORE_OIL_VOL'].fillna(method='pad')
df['BORE_GAS_VOL'] = df['BORE_GAS_VOL'].fillna(method='pad')
df['BORE_WAT_VOL'] = df['BORE_WAT_VOL'].fillna(method='pad')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   NPD_WELL_BORE_CODE        2498 non-null   float64
#  1   NPD_WELL_BORE_NAME        2500 non-null   object
#  2   ON_STREAM_HRS             2500 non-null   float64
#  3   AVG_DOWNHOLE_PRESSURE     2500 non-null   float64
#  4   AVG_DOWNHOLE_TEMPERATURE  2500 non-null   float64
#  5   AVG_DP_TUBING             2500 non-null   float64
#  6   AVG_ANNULUS_PRESS         2500 non-null   float64
#  7   AVG_CHOKE_SIZE_P          2500 non-null   float64
#  8   AVG_WHP_P                 2500 non-null   float64
#  9   AVG_WHT_P                 2500 non-null   float64
#  10  DP_CHOKE_SIZE             2500 non-null   float64
#  11  BORE_OIL_VOL              2500 non-null   float64
#  12  BORE_GAS_VOL              2500 non-null   float64
#  13  BORE_WAT_VOL              2500 non-null   float64
# dtypes: float64(13), object(1)
# memory usage: 273.6+ KB

# %%
#selecting input and output
""" selected input are ON_STREAM_HRS, AVG_CHOKE_SIZE_P, AVG_WHP_P, BORE_GAS_VOL and  BORE_WAT_VOL because 
temperature and pressure data are not measured accurate based on given data reviews. """

X=df[["ON_STREAM_HRS","AVG_CHOKE_SIZE_P","AVG_WHP_P","BORE_GAS_VOL","BORE_WAT_VOL"]] 
y=df["BORE_OIL_VOL"]

print(X.shape)
print(y.shape)
# Out:
# (2500, 5)
# (2500,)

# %%
#standardization of input data
from sklearn.preprocessing import MinMaxScaler

scal = MinMaxScaler()

new_X = scal.fit_transform(X)

# %%
new_X.shape
y.shape
# Out:
# (2500,)

# %%
Final_X = pd.DataFrame(new_X, index=X.index, columns=X.columns)
Final_X.shape
# Out:
# (2500, 5)

# %%
X = Final_X.dropna()
X.shape
# Out:
# (2500, 5)

# %%
#spliting the data for validation purpose
X_train, X_test, y_train, y_test = train_test_split(Final_X, y,test_size = 0.3, random_state=42)
# linear regression 
model_reg = LinearRegression()

model_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model_reg.predict(X_test)

# %%
y_pred
print(metrics.mean_absolute_error(y_test,y_pred))
# Out:
# 61.48797427515823
# 8590.41862101138
# 92.68451122496887

# %%
#Random forest alorithm
ram=RandomForestRegressor()
ram.fit(X_train,y_train)
y_pred_rf=ram.predict(X_test)
print("The R2 value for linear regression for oil volume production is", model_reg.score(X_test, y_test))
print("The R2 value for random forest for oil volume production is", ram.score(X_test, y_test))
# Out:
# The R2 value for linear regression for oil volume production is 0.9971809570782448
# The R2 value for random forest for oil volume production is 0.9986075281953851

# %%
print("Mean Absolute Error for Linear Regression is   ",metrics.mean_absolute_error(y_test,y_pred))
print("Mean Absolute Error for Random Forest is    ",metrics.mean_absolute_error(y_test,y_pred_rf))
# Out:
# Mean Absolute Error for Linear Regression is    61.48797427515823
# Mean Absolute Error for Random Forest is     28.47950666666667

# %%
df1=pd.read_csv("test_data_quiz.csv")
df1
# Out:
#      NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0                  5599          15/9-F-12           24.0
# 1                  5599          15/9-F-12           24.0
# 2                  5599          15/9-F-12           24.0
# 3                  5599          15/9-F-12           24.0
# 4                  5599          15/9-F-12           24.0
# ..                  ...                ...            ...
# 494                5599          15/9-F-12           24.0
# 495                5599          15/9-F-12           24.0
# 496                5599          15/9-F-12           24.0
# 497                5599          15/9-F-12           24.0
# 498                5599          15/9-F-12           24.0
#
#      AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# 0                        0                         0         52.147
# 1                        0                         0         51.696
# 2                        0                         0         51.508
# 3                        0                         0         51.184
# 4                        0                         0         50.529
# ..                     ...                       ...            ...
# 494                      0                         0         26.999
# 495                      0                         0         27.094
# 496                      0                         0            NaN
# 497                      0                         0         27.751
# 498                      0                         0         26.353
#
#      AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P  AVG_WHP_P  AVG_WHT_P  DP_CHOKE_SIZE  \
# 0               28.714          35.23351     52.147     72.510         23.500
# 1               28.870          35.46763     51.696     73.466         23.056
# 2               28.703          35.57401     51.508     72.680         22.845
# 3               28.510          35.65656     51.184     71.846         22.524
# 4               28.338          35.71326     50.529     71.837         21.861
# ..                 ...               ...        ...        ...            ...
# 494             19.916          40.27530     26.999     77.533          4.719
# 495             19.996          40.29969     27.094     76.751          4.817
# 496             20.129          40.01120     26.946     78.405          4.665
# 497             20.234          39.09910     27.751     78.220          5.513
# 498             20.306               NaN     26.353     79.191          4.287
#
#      BORE_GAS_VOL  BORE_WAT_VOL
# 0        105134.0         712.0
# 1        105584.0         716.0
# 2        103868.0         720.0
# 3        104654.0         732.0
# 4        105072.0         717.0
# ..            ...           ...
# 494       23020.0        1113.0
# 495       23270.0        1031.0
# 496       22802.0         977.0
# 497       21569.0         968.0
# 498       21807.0         989.0
#
# [499 rows x 13 columns]

# %%
df1['ON_STREAM_HRS'] = df1['ON_STREAM_HRS'].fillna(method='pad')
df1['AVG_DOWNHOLE_PRESSURE'] = df1['AVG_DOWNHOLE_PRESSURE'].fillna(method='pad')
df1['AVG_DOWNHOLE_TEMPERATURE'] = df1['AVG_DOWNHOLE_TEMPERATURE'].fillna(method='pad')
df1['AVG_DP_TUBING'] = df1['AVG_DP_TUBING'].fillna(method='pad')
df1['AVG_ANNULUS_PRESS'] = df1['AVG_ANNULUS_PRESS'].fillna(method='pad')
df1['AVG_CHOKE_SIZE_P'] = df1['AVG_CHOKE_SIZE_P'].fillna(method='pad')
df1['AVG_WHP_P'] = df1['AVG_WHP_P'].fillna(method='pad')
df1['AVG_WHT_P'] = df1['AVG_WHT_P'].fillna(method='pad')
df1['DP_CHOKE_SIZE'] = df1['DP_CHOKE_SIZE'].fillna(method='pad')
df1['BORE_GAS_VOL'] = df1['BORE_GAS_VOL'].fillna(method='pad')
df1['BORE_WAT_VOL'] = df1['BORE_WAT_VOL'].fillna(method='pad')
df1
# Out:
#      NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0                  5599          15/9-F-12           24.0
# 1                  5599          15/9-F-12           24.0
# 2                  5599          15/9-F-12           24.0
# 3                  5599          15/9-F-12           24.0
# 4                  5599          15/9-F-12           24.0
# ..                  ...                ...            ...
# 494                5599          15/9-F-12           24.0
# 495                5599          15/9-F-12           24.0
# 496                5599          15/9-F-12           24.0
# 497                5599          15/9-F-12           24.0
# 498                5599          15/9-F-12           24.0
#
#      AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# 0                        0                         0         52.147
# 1                        0                         0         51.696
# 2                        0                         0         51.508
# 3                        0                         0         51.184
# 4                        0                         0         50.529
# ..                     ...                       ...            ...
# 494                      0                         0         26.999
# 495                      0                         0         27.094
# 496                      0                         0         27.094
# 497                      0                         0         27.751
# 498                      0                         0         26.353
#
#      AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P  AVG_WHP_P  AVG_WHT_P  DP_CHOKE_SIZE  \
# 0               28.714          35.23351     52.147     72.510         23.500
# 1               28.870          35.46763     51.696     73.466         23.056
# 2               28.703          35.57401     51.508     72.680         22.845
# 3               28.510          35.65656     51.184     71.846         22.524
# 4               28.338          35.71326     50.529     71.837         21.861
# ..                 ...               ...        ...        ...            ...
# 494             19.916          40.27530     26.999     77.533          4.719
# 495             19.996          40.29969     27.094     76.751          4.817
# 496             20.129          40.01120     26.946     78.405          4.665
# 497             20.234          39.09910     27.751     78.220          5.513
# 498             20.306          39.09910     26.353     79.191          4.287
#
#      BORE_GAS_VOL  BORE_WAT_VOL
# 0        105134.0         712.0
# 1        105584.0         716.0
# 2        103868.0         720.0
# 3        104654.0         732.0
# 4        105072.0         717.0
# ..            ...           ...
# 494       23020.0        1113.0
# 495       23270.0        1031.0
# 496       22802.0         977.0
# 497       21569.0         968.0
# 498       21807.0         989.0
#
# [499 rows x 13 columns]

# %%
X1=df1[["ON_STREAM_HRS","AVG_CHOKE_SIZE_P","AVG_WHP_P","BORE_GAS_VOL","BORE_WAT_VOL"]]

# %%
#standardization of input data
from sklearn.preprocessing import MinMaxScaler

scal = MinMaxScaler()

new_X1 = scal.fit_transform(X1)

# %%
Final_X1 = pd.DataFrame(new_X1, index=X1.index, columns=X1.columns)

# %%
X1 = Final_X1.dropna()

# %%
y_pred1=model_reg.predict(X1)
y_pred2=ram.predict(X1)

# %%
df1["ln"]=y_pred1
df1["rf"]=y_pred2

# %%
df1
# Out:
#      NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  ON_STREAM_HRS  \
# 0                  5599          15/9-F-12           24.0
# 1                  5599          15/9-F-12           24.0
# 2                  5599          15/9-F-12           24.0
# 3                  5599          15/9-F-12           24.0
# 4                  5599          15/9-F-12           24.0
# ..                  ...                ...            ...
# 494                5599          15/9-F-12           24.0
# 495                5599          15/9-F-12           24.0
# 496                5599          15/9-F-12           24.0
# 497                5599          15/9-F-12           24.0
# 498                5599          15/9-F-12           24.0
#
#      AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  \
# 0                        0                         0         52.147
# 1                        0                         0         51.696
# 2                        0                         0         51.508
# 3                        0                         0         51.184
# 4                        0                         0         50.529
# ..                     ...                       ...            ...
# 494                      0                         0         26.999
# 495                      0                         0         27.094
# 496                      0                         0         27.094
# 497                      0                         0         27.751
# 498                      0                         0         26.353
#
#      AVG_ANNULUS_PRESS  AVG_CHOKE_SIZE_P  AVG_WHP_P  AVG_WHT_P  DP_CHOKE_SIZE  \
# 0               28.714          35.23351     52.147     72.510         23.500
# 1               28.870          35.46763     51.696     73.466         23.056
# 2               28.703          35.57401     51.508     72.680         22.845
# 3               28.510          35.65656     51.184     71.846         22.524
# 4               28.338          35.71326     50.529     71.837         21.861
# ..                 ...               ...        ...        ...            ...
# 494             19.916          40.27530     26.999     77.533          4.719
# 495             19.996          40.29969     27.094     76.751          4.817
# 496             20.129          40.01120     26.946     78.405          4.665
# 497             20.234          39.09910     27.751     78.220          5.513
# 498             20.306          39.09910     26.353     79.191          4.287
#
#      BORE_GAS_VOL  BORE_WAT_VOL           ln       rf
# 0        105134.0         712.0  5605.120155  5573.00
# 1        105584.0         716.0  5629.444990  5573.13
# 2        103868.0         720.0  5535.312244  5561.62
# 3        104654.0         732.0  5575.658596  5573.21
# 4        105072.0         717.0  5602.565733  5573.00
# ..            ...           ...          ...      ...
# 494       23020.0        1113.0  1061.417447  1173.99
# 495       23270.0        1031.0  1094.590355  1190.46
# 496       22802.0         977.0  1081.511580  1169.44
# 497       21569.0         968.0  1014.157675  1091.64
# 498       21807.0         989.0  1023.054673  1112.52
#
# [499 rows x 15 columns]

# %%
df1.to_excel("output_kripal.xlsx")
